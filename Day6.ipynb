# %% [markdown]
# ## Exercise 1
# For each task, say Regression or Classification:
#
# * Predicting tomorrow’s temperature- Regression
# * Predicting whether an email is spam- Classification
# * Predicting stock price- Regression
# * Predicting if a student passes- Classification
#
# ## Exercise 2
# Given the model:
#
# 𝑦 = 3*x1* − 1.5*x2* + 0.2*x3* + 10
#
# Answer:
# * Which feature has the strongest influence?- x1
# * Which feature reduces the prediction?- x2
# * What happens if *x2* increases by 2 units?- prediction decreases by 3 units
#
# ## Exercise 3
# Given:
#
# y = 2*x1* + 4*x2* + 1
#
# Compute 𝑦 for:
# * *x1*=1, *x2*=2 => y= 12
# * *x1*=0, *x2*=-1 => y= -3
